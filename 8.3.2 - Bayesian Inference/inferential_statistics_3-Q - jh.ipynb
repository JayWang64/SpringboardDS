# %% [markdown]
# # Inferential Statistics III - Bayesian

# %% [markdown]
# ## Introduction

# %% [markdown]
# In the last two subunits, you've encountered two schools for performing inference from samples.
#
# The Frequentist school calls upon a body of theory established over the past couple of centuries or so. Under certain assumptions and conditions, this allows us to calculate what we would expect to see if an experiment were to be repeated again and again and again. The expected value of the average of a sample is one such statistic we can calculate a result for, even if the originating distribution is far from normal.
#
# The bootstrap school, on the other hand, literally does (virtually) run that experiment again and again and again and empirically observes the multitude of outcomes. It then empirically calculates a statistic of interest. While this can be for exactly the same statistics that frequentism calculates (e.g. the mean of a sample) this empirical approach can also perform inference on statistics that do not have well known sampling distributions.
#
# Because of the requirement to repeat many, many redraws (with replacement) from the sample, this approach only became feasible with modern computing power.
#
# And thus we come to the Bayesian school of inference. Here we frame our probabilities not so much in terms of "how many times would I expect this event to occur if the experiment were to be rerun many times" but rather in terms of
#
# "what is my belief in the likelihood of this event occurring?"
#
# In a Bayesian probabilistic programming context, we can build models for systems and then let the data tell us how likely certain values for our model parameters are. This can be a very useful way to incorporate prior knowledge and deal with limited data. It can just be more than a _little_ fiddly to produce a good model!

# %% [markdown]
# ## Medical charge data set

# %% [markdown]
# For the final mini-project of the stats unit, you'll once again return to the medical charge data you've used for the other mini-projects. Previously, we considered whether we believed that the actual average(non-insured) charge had fallen below a certain threshold.
#
# The hospital is now reviewing its financial resiliency plan, which requires a model for revenue under a range of conditions that include the number of patients treated.
#
# Its current model is based on a confidence interval for the mean, and scaling that by different numbers of patients for each scenario.
#
# This approach has a number of limitations,
# > most acutely the breakdown of the central limit theorem for low patient volumes;
# > the current model does not do a good job of reflecting the variability in revenue you would see as the number of cases drops.
#
# A bootstrap approach would return samples of the same size as the original.
# Taking subsamples would restrict the sampling to the values already present in the original sample and would not do a good job of representing the actual variability you might see.
#
# What is needed is a better model of individual charges.
#
# So the problem here is that we want to model the distribution of individual charges and _we also really want to be able to capture our uncertainty about that distribution_ so we can better capture the range of values we might see.
#
# This naturally leads us to a powerful, probabilistic approach — we'll use the pymc3 library to perform Bayesian inference.

# %% [markdown]
# ### Loading the data and performing an initial view

# %%
import pymc3 as pm
import pandas as pd
import numpy as np
from numpy.random import seed
import matplotlib.pyplot as plt
from scipy.stats import gamma
# there has been some incompatibilty between theano and numpy, if you encounter
# an error with the latest packages from anaconda, then the included
# package-list-txt should allow you to create a conda environment with compatible
# packages.

# %%
medical = pd.read_csv('data/insurance2.csv')

# %%
medical.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
insurance = medical.charges[medical.insuranceclaim == 1]
insurance
# Out:
# 0       16884.92400
# 1        1725.55230
# 4        3866.85520
# 6        8240.58960
# 10       2721.32080
#            ...
# 1330    12629.16560
# 1331    10795.93733
# 1334     2205.98080
# 1335     1629.83350
# 1337    29141.36030
# Name: charges, Length: 783, dtype: float64

# %%
no_insurance = medical.charges[medical.insuranceclaim == 0]
no_insurance
# Out:
# 2        4449.46200
# 3       21984.47061
# 5        3756.62160
# 7        7281.50560
# 8        6406.41070
#            ...
# 1324     4239.89265
# 1328    22395.74424
# 1332    11411.68500
# 1333    10600.54830
# 1336     2007.94500
# Name: charges, Length: 555, dtype: float64

# %%
n_ins = len(insurance)
n_ins
# Out:
# 783

# %%
n_no_ins = len(no_insurance)
n_no_ins
# Out:
# 555

# %%
_ = plt.hist(insurance, bins=30, alpha=0.5, label='insurance claim')
_ = plt.hist(no_insurance, bins=30, alpha=0.5, label='not insurance claim')
_ = plt.xlabel('Charge amount')
_ = plt.ylabel('Frequency')
_ = plt.legend()

# %% [markdown]
# We may suspect from the above that there is some sort of exponential-like distribution at play here. The charges that were not insurance claims seem most like this. The insurance claim charges may possibly be multimodal. The gamma distribution may be applicable and we could test this for the distribution of charges that weren't insurance claims first.
#
# Developing our new method for the easiest looking case first is a common and sound approach that can demonstrate a minimum viable solution/product and get, or keep, stakeholders on board.

# %% [markdown]
# ### Initial parameter estimation

# %% [markdown]
# An initial guess for the gamma distribution's $\alpha$ and $\beta$ parameters can be made as described [here](https://wiki.analytica.com/index.php?title=Gamma_distribution).

# %%
alpha_est = np.mean(no_insurance)**2 / np.var(no_insurance)
beta_est = np.var(no_insurance) / np.mean(no_insurance)
alpha_est, beta_est
# Out:
# (1.8759059725250895, 4702.486170152818)

# %% [markdown]
# ### Initial simulation

# %% [markdown]
# Let's draw the same number of random variates from this distribution and compare to our observed data.

# %%
seed(47)
no_ins_model_rvs = gamma(alpha_est, scale=beta_est).rvs(n_no_ins)

# %%
_ = plt.hist(no_ins_model_rvs, bins=30, alpha=0.5, label='no insurance - simulated')
_ = plt.hist(no_insurance, bins=30, alpha=0.5, label='no insurance - observed')
_ = plt.xlabel('Charge amount')
_ = plt.ylabel('Frequency')
_ = plt.legend()

# %% [markdown]
# Well it doesn't look too bad! We're not a million miles off. But can we do better? We have a plausible form for the distribution of charge amounts and potential values for that distribution's parameters so we can already draw random variates from that distribution to perform simulations. But we don't know if we have a _best_ estimate for the population parameters, and we also only have a single estimate each for $\alpha$ and $\beta$; we aren't capturing our uncertainty in their values.
#
# Can we take a Bayesian inference approach to estimate the parameters?

# %% [markdown]
# ### Creating a PyMC3 model

# %%
# PyMC3 Gamma seems to use rate = 1/beta
rate_est = 1/beta_est
# Initial parameter estimates we'll use below
alpha_est, rate_est
# Out:
# (1.8759059725250895, 0.00021265346963636103)

# %%
beta_est
# Out:
# 4702.486170152818

# %%
1/rate_est
# Out:
# 4702.486170152818

# %% [markdown]
# # Question 1

# %% [markdown]
# __Q:__ You are now going to create your own PyMC3 model!
# 1. Use an [exponential](https://docs.pymc.io/api/distributions/continuous.html#pymc3.distributions.continuous.Exponential) prior for alpha. Call this stochastic variable `alpha_`.
# 2. Similarly, use an exponential prior for the rate ([$1/\beta$](https://wiki.analytica.com/index.php?title=Gamma_distribution)) parameter in PyMC3's [Gamma](https://docs.pymc.io/api/distributions/continuous.html#pymc3.distributions.continuous.Gamma). Call this stochastic variable `rate_` (but it will be supplied as `pm.Gamma`'s `beta` parameter). Hint: to set up a prior with an exponential distribution for $x$ where you have an initial estimate for $x$ of $x_0$, use a scale parameter of $1/x_0$.
# 5. Create your Gamma distribution with your `alpha_` and `rate_` stochastic variables and the observed data.
# 6. Perform 10000 draws.

# %% [markdown]
# Hint: you may find it helpful to work backwards. Start with your `pm.Gamma`, and note the required stochastic variables `alpha` and `beta`. Then, before that, you need to create those stochastic variables using `pm.Exponential` and the correct parameters.

# %% [markdown]
# __A:__

# %%
#10k draws
n = 10000

# %%
# https://stackoverflow.com/questions/58160291/pymc3-nuts-sampler-whats-happening-here
# https://docs.pymc.io/api/distributions/continuous.html#pymc3.distributions.continuous.Exponential
# https://wiki.analytica.com/index.php?title=Gamma_distribution
# https://towardsdatascience.com/estimating-probabilities-with-bayesian-modeling-in-python-7144be007815

# https://stats.stackexchange.com/questions/429271/why-would-they-pick-a-gamma-distribution-here

# %%
#instantiate a model

no_insurance_model = pm.Model()
with no_insurance_model:
    alpha_ = pm.Exponential('alpha_', 1/alpha_est)
    rate_ = pm.Exponential('rate_', beta_est)
    g = pm.Gamma(name='g', 
                 alpha=alpha_,
                 beta=rate_,
                 observed=no_insurance)
    trace = pm.sample(draws=n)
# Out:
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '2980' (I am process '31008')
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [rate_, alpha_]
# Sampling 4 chains, 0 divergences: 100%|██████████| 42000/42000 [01:30<00:00, 463.62draws/s]

# %% [markdown]
# If you get a warning about acceptance probability not matching the target, and that it's around 0.88 when it should be close to 0.8, don't worry. We encourage you to read up on this and see if you can adjust the parameters and/or arguments to pm.sample, but if your model runs without any additional warnings or errors then you should be doing great!

# %% [markdown]
# # Question 2

# %% [markdown]
# __Q:__ Explore your posteriors for $\alpha$ and $\beta$ (from the trace).
# * Calculate the 95% credible interval for $\alpha$ and $\beta$.
# * Plot your posterior values of $\alpha$ and $\beta$ (both line plots and histograms).
# * Mark your CIs on the histograms.
# * Do they look okay? What would bad plots look like?

# %% [markdown]
# __A:__

# %% [markdown]
# # get num bins ===========================

# %%
def get_num_bins(np_array):
    '''
    Gets the optimal number of bins for the historgram
    source: https://stats.stackexchange.com/questions/798/calculating-optimal-number-of-bins-in-a-histogram
    '''
    new_series= pd.Series(np_array)
    bins = 0
    maxv = max(new_series)
    minv = min(new_series)
    new_series_q75, new_series_q25 = np.percentile(new_series, [75,25])    
    iqr = new_series_q75 - new_series_q25
    h = 2 * iqr / len(new_series) ** (1/3)
    bins = (maxv - minv) / h
    return int(bins)

# %%
trace.varnames
# Out:
# ['alpha__log__', 'rate__log__', 'alpha_', 'rate_']

# %%
# credible interval aka the probability density

# %%
pm.stats.hpd(ary=no_insurance, credible_interval=0.95)
# Out:
# array([ 1241.565 , 23288.9284])

# %%
alpha_vals_ = trace.get_values(varname='alpha_')
pm.stats.hpd(ary=alpha_vals_, credible_interval=0.95)
# Out:
# array([1.98190053, 2.48192024])

# %%
beta_vals_ = trace.get_values(varname='rate_')
pm.stats.hpd(ary=beta_vals_, credible_interval=0.95)
# Out:
# array([0.0002216 , 0.00028486])

# %%
alpha__log__vals_ = trace.get_values(varname='alpha__log__')
pm.stats.hpd(ary=alpha__log__vals_, credible_interval=0.95)
# Out:
# array([0.68991016, 0.91385365])

# %%
rate__log__vals_ = trace.get_values(varname='rate__log__')
pm.stats.hpd(ary=rate__log__vals_, credible_interval=0.95)
# Out:
# array([-8.41463899, -8.16352572])

# %% [markdown]
# # Bins for alpha

# %% [markdown]
# # ALPHA

# %%
_ = plt.hist(alpha_vals_, bins=get_num_bins(alpha_vals_))
_ = plt.title('My_alpha')
_ = plt.xlabel('alpha')
_ = plt.ylabel('Qty')

_ = plt.axvline(pm.stats.hpd(ary=alpha_vals_, credible_interval=0.95)[0], color='r')
_ = plt.axvline(pm.stats.hpd(ary=alpha_vals_, credible_interval=0.95)[1], color='r')

plt.show()

# %% [markdown]
# # BETA

# %%
_ = plt.hist(beta_vals_, bins=get_num_bins(beta_vals_))
_ = plt.title('My_beta')
_ = plt.xlabel('beta')
_ = plt.ylabel('Qty')

_ = plt.axvline(pm.stats.hpd(ary=beta_vals_, credible_interval=0.95)[0], color='r')
_ = plt.axvline(pm.stats.hpd(ary=beta_vals_, credible_interval=0.95)[1], color='r')

plt.show()

# %% [markdown]
# __Q:__ Play around with some of the built-in diagnostic plots for your model. We suggest at least checking out the traceplot for alpha and beta. How do they look?

# %% [markdown]
# __A:__

# %%
pm.traceplot(trace)
# Out:
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000149C6E56A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000149CCBF2B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000149CCA1FBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000149CCC3B808>]],
#       dtype=object)

# %% [markdown]
# # Question 2

# %% [markdown]
# __Q:__ Take your best shot at a new simulated sequence of medical charges using scipy.stat's gamma distribution. Don't forget the difference between functions that take $\beta$ and functions that use $1/\beta$ for the scale parameter. Simulate a data set the same size as the number of observations in the data and overlay the two histograms (simulated and observed).

# %% [markdown]
# __A:__

# %%
seed(47)

# %%
alpha2_est = np.mean(insurance)**2 / np.var(insurance)
beta2_est = np.var(insurance) / np.mean(insurance)
alpha2_est, beta2_est
# Out:
# (1.3690149379517424, 11996.894863039557)

# %%
# PyMC3 Gamma seems to use rate = 1/beta
rate2_est = 1/beta2_est

# Initial parameter estimates we'll use below
alpha2_est, rate2_est
# Out:
# (1.3690149379517424, 8.335490236568081e-05)

# %%
#instantiate a model

insurance_model = pm.Model()
with insurance_model:
    alpha2_ = pm.Exponential('alpha2_', 1/alpha2_est)
    rate2_ = pm.Exponential('rate2_', beta2_est)
        
    g2 = pm.Gamma(name='g2', 
                 alpha=alpha2_,
                 beta=rate2_,
                 observed=insurance)
    trace2 = pm.sample(draws=n_ins)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [rate2_, alpha2_]
# Sampling 4 chains, 0 divergences: 100%|██████████| 5132/5132 [00:16<00:00, 313.59draws/s]
# The acceptance probability does not match the target. It is 0.8799537397544274, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %% [markdown]
# # ignore
#
# mu_est = np.mean(insurance)
# sigma_est = np.var(insurance)
# mu_est, sigma_est

# %% [markdown]
# # ignore
#
# insurance_model = pm.Model()
# with insurance_model:
#
#     mu = pm.Exponential('mu', mu_est)
#     sigma = pm.Exponential('sigma', sigma_est)
#
#     alpha = mu**2 / sigma**2
#     beta = mu / sigma**2
#
#     y_obs = pm.Gamma('y_obs', alpha=alpha, beta=beta, observed=insurance)
#     trace2 = pm.sample(draws=n_ins)

# %%
trace2.varnames
# Out:
# ['alpha2__log__', 'rate2__log__', 'alpha2_', 'rate2_']

# %%
# credible interval aka the probability density

# %%
pm.stats.hpd(ary=insurance, credible_interval=0.95)
# Out:
# array([ 1131.5066 , 44585.45587])

# %%
alpha2_vals_ = trace2.get_values(varname='alpha2_')
pm.stats.hpd(ary=alpha2_vals_, credible_interval=0.95)
# Out:
# array([1.19183958, 1.42625851])

# %%
alpha2_vals_ = trace2['alpha2_']
alpha2_vals_
# Out:
# array([1.36316699, 1.38537062, 1.42964041, ..., 1.33438178, 1.33438178,
#        1.33438178])

# %%
alpha2_vals_
# Out:
# array([1.36316699, 1.38537062, 1.42964041, ..., 1.33438178, 1.33438178,
#        1.33438178])

# %%
np.mean(alpha2_vals_)
# Out:
# 1.3095071484014948

# %%
beta2_vals_ = trace2.get_values(varname='rate2_')
pm.stats.hpd(ary=beta2_vals_, credible_interval=0.95)
# Out:
# array([7.10344501e-05, 8.83871578e-05])

# %%
alpha2__log__vals_ = trace2.get_values(varname='alpha2__log__')
pm.stats.hpd(ary=alpha2__log__vals_, credible_interval=0.95)
# Out:
# array([0.18391222, 0.36229616])

# %%
rate2__log__vals_ = trace2.get_values(varname='rate2__log__')
pm.stats.hpd(ary=rate2__log__vals_, credible_interval=0.95)
# Out:
# array([-9.54454912, -9.32739665])

# %% [markdown]
# # ALPHA 2

# %%
_ = plt.hist(alpha2_vals_, bins=get_num_bins(alpha2_vals_))
_ = plt.title('My_alpha2')
_ = plt.xlabel('alpha2')
_ = plt.ylabel('Qty')

_ = plt.axvline(pm.stats.hpd(ary=alpha2_vals_, credible_interval=0.95)[0], color='r')
_ = plt.axvline(pm.stats.hpd(ary=alpha2_vals_, credible_interval=0.95)[1], color='r')

plt.show()

# %% [markdown]
# # BETA 2

# %%
_ = plt.hist(beta2_vals_, bins=get_num_bins(beta2_vals_))
_ = plt.title('My_beta2')
_ = plt.xlabel('beta2')
_ = plt.ylabel('Qty')

_ = plt.axvline(pm.stats.hpd(ary=beta2_vals_, credible_interval=0.95)[0], color='r')
_ = plt.axvline(pm.stats.hpd(ary=beta2_vals_, credible_interval=0.95)[1], color='r')

plt.show()

# %%
pm.traceplot(trace2)
# Out:
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# C:\Users\Justin\.conda\envs\python37\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000149C5E2E208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000149C821C1C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000149C8244A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000149C8223C08>]],
#       dtype=object)

# %%
# Simulate a data set the same size as the number of observations in the data 
# and overlay the two histograms (simulated and observed).

# %%
# trace2.varnames
# simulated_vals = trace2["alpha2_"][:, None]
# simulated_vals

# %% [markdown]
# # Ask Blake

# %%
# not sure if this is the correct approach?

#my thinking is the take hte avg alpha and betas that were calculated from the 
# bayesian model and apply them to this gamma function to simulate the values

alpha2_sim = np.mean(alpha2_vals_)
beta2_sim = np.mean(beta2_vals_)

# %%
seed(47)
ins_model_rvs = gamma(alpha2_sim,scale=1/beta2_sim).rvs(n_ins)
ins_model_rvs
# Out:
# array([4.45646364e+03, 3.66176277e+04, 3.27378014e+03, 5.07851137e+04,
#        8.94663719e+03, 6.27381579e+03, 3.94460277e+03, 3.88193814e+03,
#        1.84972737e+04, 2.49827098e+04, 2.07961411e+03, 1.29016693e+04,
#        1.91515381e+04, 1.44571847e+04, 1.82743436e+04, 1.99714654e+02,
#        7.36131880e+03, 3.14178486e+03, 1.95413636e+04, 1.18807988e+04,
#        5.46854062e+02, 1.59323846e+04, 1.43113623e+04, 4.01457374e+03,
#        5.63735982e+04, 2.55530002e+04, 1.59705428e+04, 1.73891717e+04,
#        3.90325234e+03, 1.81750888e+04, 1.63828618e+04, 3.56926111e+04,
#        1.30463157e+04, 1.62845296e+04, 2.80262153e+04, 1.19099613e+04,
#        2.97645225e+04, 1.74094283e+02, 5.77816728e+04, 3.98806317e+04,
#        1.13310219e+04, 3.28417735e+04, 3.88536099e+04, 1.53889386e+04,
#        2.03826562e+04, 2.07812714e+04, 2.00085315e+04, 1.08324976e+04,
#        8.96099279e+03, 2.65045365e+02, 2.90325255e+04, 2.54951660e+04,
#        2.09571500e+04, 5.01380606e+04, 2.78342561e+04, 1.26817515e+04,
#        2.38116221e+04, 6.62075767e+03, 4.03485600e+04, 1.17579649e+04,
#        4.55534892e+03, 6.76407729e+03, 2.52986771e+04, 6.72260058e+03,
#        3.11421265e+04, 6.91387396e+04, 2.97836289e+03, 3.77356349e+04,
#        1.20080399e+04, 1.14665233e+04, 9.98258122e+02, 2.80621313e+03,
#        1.76623786e+04, 1.42473808e+04, 1.93829353e+04, 2.13192882e+04,
#        1.94465721e+04, 3.46526627e+03, 5.19683423e+03, 1.94205727e+04,
#        2.02657549e+04, 1.96331605e+04, 1.19872654e+04, 1.01075163e+04,
#        1.51417380e+04, 1.01837973e+04, 1.94373858e+04, 6.45071615e+03,
#        3.74036637e+03, 1.56911202e+04, 5.38851073e+03, 9.73935540e+04,
#        1.01556860e+04, 2.07851167e+04, 7.58751176e+03, 8.64293476e+03,
#        1.17491335e+03, 1.87913225e+04, 9.50908623e+03, 4.90366341e+04,
#        1.41179650e+04, 6.94215827e+03, 3.59848659e+04, 1.19608351e+04,
#        1.50359947e+04, 1.73820200e+03, 2.39326578e+04, 9.69169594e+03,
#        7.64243393e+03, 8.11250856e+03, 2.52882454e+04, 8.32270513e+03,
#        7.57678733e+03, 5.79825924e+02, 9.05602238e+03, 2.87750663e+04,
#        3.45908614e+03, 9.23928181e+03, 1.06594073e+03, 3.35436586e+04,
#        5.24211082e+04, 1.58098339e+04, 1.72842993e+04, 5.93502256e+03,
#        2.46039662e+04, 3.31020701e+03, 5.27048757e+04, 1.84556538e+03,
#        8.36354925e+03, 9.03751870e+03, 5.96193826e+04, 1.31608305e+04,
#        2.25049329e+04, 1.95131551e+04, 7.53234600e+02, 1.70583316e+04,
#        3.80350995e+04, 3.29157416e+04, 5.05309313e+04, 1.02598761e+03,
#        2.18965875e+03, 1.94776868e+04, 2.78962427e+03, 2.88268343e+03,
#        3.46996895e+04, 1.67821582e+04, 2.23192176e+03, 6.83490559e+03,
#        7.21415953e+01, 1.01102095e+04, 1.94038494e+04, 2.02029209e+03,
#        1.34106520e+04, 9.80097174e+03, 3.35624614e+03, 3.02981374e+04,
#        3.98341576e+03, 2.30139455e+04, 1.18392191e+04, 2.10380483e+04,
#        1.75727027e+03, 7.28293168e+03, 5.74882774e+03, 1.04631663e+04,
#        1.46952878e+04, 3.17095129e+04, 1.59193046e+04, 2.46588073e+04,
#        2.41811950e+04, 1.25549200e+04, 2.24557953e+04, 2.24150543e+04,
#        1.75296482e+04, 2.16058871e+04, 3.53799718e+04, 2.94961624e+03,
#        2.00362953e+04, 1.17337789e+04, 1.28666585e+04, 2.84477468e+04,
#        1.22024346e+04, 1.96053949e+03, 1.41868216e+04, 9.66057062e+03,
#        8.76172603e+03, 5.74857657e+04, 2.54780763e+04, 1.39930639e+04,
#        3.89330549e+04, 2.03445451e+04, 2.60770659e+04, 1.15569430e+04,
#        2.28868827e+04, 3.24689288e+04, 4.03241772e+04, 6.37126288e+03,
#        1.54181634e+04, 7.06465042e+03, 6.66402252e+03, 5.75994393e+03,
#        1.49933163e+04, 4.83319178e+04, 3.82229435e+04, 7.40588309e+03,
#        5.32288209e+04, 2.28735814e+04, 1.42831257e+03, 4.48337613e+04,
#        3.45755132e+04, 2.93417691e+03, 1.94936106e+03, 5.57388500e+04,
#        2.64712469e+04, 1.21278656e+04, 2.25339968e+03, 2.75679578e+03,
#        2.60923632e+03, 3.56740822e+04, 3.85402792e+04, 4.52752470e+03,
#        1.67994606e+04, 2.03103399e+04, 5.96955448e+04, 2.95136433e+04,
#        4.63270204e+03, 6.27526086e+03, 1.30572263e+04, 9.78008526e+03,
#        8.95988350e+03, 2.38589395e+04, 5.33091283e+04, 1.77573562e+04,
#        3.02052346e+03, 2.47424461e+03, 4.54663659e+03, 2.60106576e+04,
#        3.70472342e+03, 4.08855987e+04, 1.19436007e+04, 3.70982513e+04,
#        1.82680367e+04, 8.00534847e+03, 4.08600229e+04, 9.90748211e+02,
#        2.42698849e+04, 9.42765880e+03, 8.07917917e+03, 8.07952587e+02,
#        9.47188032e+03, 3.13670134e+04, 2.79642196e+04, 7.71113607e+03,
#        2.75326889e+04, 5.00051410e+03, 7.60323485e+03, 2.62954743e+04,
#        1.91896179e+04, 2.41428546e+04, 4.70148518e+03, 1.94470347e+04,
#        3.50831258e+03, 3.25968537e+04, 5.10718108e+03, 2.33532528e+04,
#        3.70529271e+03, 7.61433871e+03, 7.77835741e+03, 3.86356978e+04,
#        2.87440484e+04, 1.86708468e+03, 1.71176258e+04, 1.83763774e+04,
#        5.43344936e+03, 8.40214584e+03, 1.28068290e+03, 1.94669218e+03,
#        1.93293046e+04, 2.89351914e+04, 5.09952312e+03, 4.84729825e+03,
#        6.22768380e+03, 1.00638692e+03, 2.24600251e+04, 1.74555701e+04,
#        1.33029581e+04, 6.99956648e+03, 7.94175380e+03, 1.03168937e+04,
#        5.43731006e+03, 8.12567437e+03, 1.53536753e+04, 2.57737638e+04,
#        8.79108096e+03, 5.79071197e+02, 1.68560622e+04, 2.10074854e+04,
#        7.79764948e+03, 4.25797547e+02, 1.99405392e+04, 1.18182300e+04,
#        4.92581464e+03, 2.50631558e+04, 8.47102467e+03, 2.17918526e+04,
#        2.00387571e+04, 9.61851376e+03, 2.33770823e+04, 1.10180368e+04,
#        1.59606918e+04, 9.21308560e+03, 2.04860057e+04, 1.30447290e+04,
#        1.33729687e+04, 5.34881407e+04, 3.03938149e+04, 9.12063568e+04,
#        2.94220444e+03, 3.30530701e+04, 1.83076363e+04, 6.39864551e+03,
#        1.99213952e+04, 1.16387280e+04, 1.59372052e+04, 2.03931071e+04,
#        2.95826301e+03, 3.43256197e+03, 5.16998077e+04, 5.48882864e+03,
#        9.21296338e+03, 2.12535345e+04, 6.35601573e+03, 7.28104222e+03,
#        1.83429693e+04, 6.44922139e+03, 3.82075138e+03, 2.10030849e+03,
#        1.28063278e+04, 1.56033854e+04, 1.17926461e+03, 7.32079273e+03,
#        2.00436281e+03, 9.63160169e+03, 8.25160812e+03, 9.34177726e+03,
#        6.76507729e+03, 2.44669156e+04, 5.77765102e+04, 4.19768447e+03,
#        2.04804077e+03, 2.93867545e+03, 4.14068399e+04, 2.50139391e+04,
#        1.85898524e+04, 1.85144098e+04, 2.37068956e+04, 6.71758803e+03,
#        4.27637777e+03, 6.23384280e+03, 4.40052708e+03, 2.60132684e+03,
#        8.17486118e+03, 1.29281963e+04, 2.03885902e+04, 6.73104902e+03,
#        2.41213860e+04, 3.55474533e+04, 1.70720383e+04, 7.19010834e+03,
#        1.36732159e+04, 5.11379593e+03, 1.74807896e+04, 1.04354296e+04,
#        2.40819839e+04, 2.50983482e+04, 8.59448620e+01, 1.59692977e+04,
#        1.86284579e+04, 6.13887079e+03, 1.95356797e+04, 3.84674970e+04,
#        4.72173878e+03, 3.21639392e+04, 1.95161613e+04, 1.23516410e+04,
#        1.84507738e+04, 1.03484859e+04, 1.18410157e+03, 2.14822931e+03,
#        1.78072847e+04, 5.42028406e+03, 6.24417307e+03, 2.91154471e+04,
#        1.73841654e+04, 9.42133008e+03, 6.37580200e+03, 3.34605869e+03,
#        5.17618438e+03, 2.38058803e+04, 1.15961891e+04, 2.14851333e+03,
#        6.56307153e+03, 3.49167257e+04, 2.16881659e+04, 1.40243166e+04,
#        4.82650084e+03, 2.84751047e+03, 1.77932800e+04, 1.33504648e+04,
#        2.87680599e+04, 6.72516611e+03, 2.47044660e+03, 5.79271029e+03,
#        8.03959921e+03, 3.44431694e+03, 1.22857410e+04, 6.13906416e+03,
#        1.95821889e+04, 2.74564523e+04, 5.13573949e+03, 3.79992185e+03,
#        1.86747820e+04, 1.60325708e+04, 4.74369898e+03, 2.02136528e+04,
#        2.75637626e+03, 3.25729422e+04, 3.07698853e+04, 3.28981737e+04,
#        1.81386085e+04, 1.53103261e+04, 1.36805916e+04, 3.49359622e+04,
#        1.05154381e+04, 8.54880775e+03, 8.91751574e+03, 2.54864202e+04,
#        3.58938614e+03, 1.19225518e+04, 6.76424549e+04, 5.51942343e+03,
#        1.96818232e+04, 3.03159178e+02, 2.95486738e+03, 1.47245006e+04,
#        1.50814867e+04, 4.94294171e+03, 6.06864175e+03, 6.20377344e+03,
#        6.58665380e+03, 9.26246495e+03, 1.09851974e+04, 1.12451825e+04,
#        4.89224130e+03, 2.02103031e+04, 1.04500579e+04, 6.25525332e+04,
#        1.78600332e+04, 2.82437783e+04, 2.30163362e+04, 2.59848533e+04,
#        1.00185539e+04, 1.13508218e+04, 2.03795290e+04, 4.30677353e+03,
#        6.86539604e+02, 7.77674408e+03, 3.42033493e+04, 3.17827995e+04,
#        4.21835819e+03, 1.07005419e+04, 2.13255781e+04, 3.57052964e+03,
#        4.45574072e+03, 1.21742204e+04, 4.49269758e+03, 1.29313924e+04,
#        1.87374149e+04, 7.33316101e+03, 5.71971316e+03, 3.53253530e+03,
#        1.47403225e+04, 2.66626632e+04, 1.32287879e+04, 4.28612053e+04,
#        9.55075993e+03, 1.23862010e+04, 4.35703517e+04, 2.28862055e+04,
#        9.29737764e+03, 4.75153203e+03, 8.00158891e+03, 2.78187473e+04,
#        1.67726760e+03, 2.67330273e+03, 1.37545817e+04, 1.18681852e+04,
#        3.12533567e+02, 9.65553612e+03, 8.51079533e+03, 1.66041310e+04,
#        2.11578841e+04, 1.87520438e+04, 1.18629378e+04, 1.12138921e+04,
#        2.24637383e+03, 2.24476479e+04, 7.27756452e+03, 9.26988921e+03,
#        2.31507361e+03, 2.37083230e+04, 8.42293924e+03, 3.47967702e+02,
#        8.66125899e+03, 4.28425746e+04, 5.08107373e+03, 5.52870883e+04,
#        4.05061063e+04, 6.23325348e+03, 1.22150728e+04, 5.28790304e+03,
#        1.03224789e+04, 1.68738470e+04, 7.26010943e+03, 3.56883608e+04,
#        1.93669766e+04, 9.25008303e+03, 1.22656147e+04, 1.50602549e+04,
#        2.04670726e+04, 1.64692942e+04, 1.10892780e+04, 4.30338588e+04,
#        2.20770903e+02, 1.11785129e+04, 1.39627888e+04, 3.70473009e+03,
#        1.90418338e+04, 6.22087809e+03, 3.26414447e+03, 1.20830667e+04,
#        5.80122835e+03, 2.68262703e+04, 3.11154711e+04, 8.33618857e+03,
#        4.75542576e+03, 5.84238349e+04, 1.60346451e+03, 8.24303152e+03,
#        4.70204892e+02, 6.27931848e+03, 1.15179794e+04, 8.48535087e+03,
#        9.45255253e+03, 5.00405338e+04, 4.09139781e+04, 3.96732864e+04,
#        2.39597175e+03, 1.13947921e+04, 4.31927942e+02, 3.79004984e+03,
#        1.52015861e+04, 1.27358171e+04, 1.14105011e+04, 1.89122121e+04,
#        3.47563789e+03, 5.78366394e+03, 1.83563193e+04, 1.12576794e+04,
#        3.51246811e+04, 6.48218891e+03, 4.08278433e+03, 2.39919869e+04,
#        1.56434299e+04, 1.16428063e+04, 7.99984809e+03, 3.11676462e+03,
#        1.12453562e+04, 1.11159530e+04, 3.72615739e+04, 1.56311821e+03,
#        2.93102248e+03, 1.54434629e+04, 1.18765966e+04, 4.64267143e+02,
#        1.25535713e+03, 4.30232412e+03, 6.67101349e+03, 1.14423101e+04,
#        1.68242760e+04, 5.85478348e+03, 1.10455674e+04, 2.43873952e+04,
#        1.34305252e+04, 1.38567637e+03, 2.67110937e+04, 8.56931623e+03,
#        1.16822996e+04, 1.02742601e+04, 1.35188790e+04, 2.55867287e+04,
#        1.41570305e+04, 1.12725547e+04, 4.20765712e+04, 1.26061822e+04,
#        2.04168136e+04, 2.45533227e+04, 1.40587022e+04, 5.89835799e+03,
#        1.81331822e+04, 1.60458184e+04, 7.97526687e+02, 1.77409110e+03,
#        2.87129203e+03, 8.64785658e+03, 9.52519430e+02, 2.33379504e+03,
#        1.93776341e+04, 6.92692402e+03, 2.95732114e+04, 2.17112511e+04,
#        2.71347168e+04, 2.03914837e+04, 2.31119061e+04, 3.42092306e+04,
#        1.00657172e+04, 2.92498134e+04, 9.49533397e+03, 8.15777213e+03,
#        1.66764136e+04, 8.34676233e+03, 2.64679420e+04, 1.60173137e+03,
#        4.15548771e+03, 1.24069094e+03, 1.55952393e+04, 1.12771049e+04,
#        2.09581755e+04, 8.74246222e+03, 1.68879689e+03, 2.05911425e+04,
#        4.92192884e+03, 3.62377454e+04, 4.81812900e+04, 7.82027136e+03,
#        5.05682941e+03, 3.26496077e+03, 4.03290029e+03, 1.54598086e+04,
#        2.13521826e+04, 1.83091507e+04, 4.48158981e+03, 4.40633691e+02,
#        2.13881618e+04, 1.54832458e+04, 1.17437743e+04, 9.17824064e+04,
#        1.39123890e+03, 3.53156844e+03, 3.82812127e+04, 1.78632946e+04,
#        9.44774296e+03, 2.51341737e+03, 8.61366419e+03, 2.80168026e+04,
#        8.07502105e+03, 2.46706316e+04, 2.82055669e+04, 3.24457421e+04,
#        5.51659607e+03, 2.16395561e+04, 1.18108706e+04, 4.42887855e+03,
#        9.76940311e+03, 4.80226494e+03, 4.58859391e+03, 1.27865340e+04,
#        2.02496539e+04, 1.97282181e+04, 4.81537844e+02, 6.65743553e+03,
#        4.64400882e+04, 3.51355400e+03, 2.36145679e+04, 3.23328463e+03,
#        1.58589854e+04, 5.82272575e+04, 5.69774498e+03, 2.58352863e+04,
#        2.13501832e+04, 1.07949850e+04, 1.76943128e+04, 1.44121246e+04,
#        9.95353194e+03, 1.96103620e+04, 1.21540310e+04, 2.32490819e+04,
#        8.53483804e+03, 9.72154861e+03, 2.19159307e+03, 5.93601154e+03,
#        1.24020045e+04, 2.44209518e+04, 1.22765325e+04, 6.49660495e+03,
#        4.25741421e+04, 2.59803567e+04, 2.27091301e+04, 1.06671922e+04,
#        5.08108831e+03, 2.14089810e+04, 2.70140627e+04, 7.92732174e+04,
#        4.48061660e+04, 4.29976871e+04, 8.73215991e+03, 1.11232009e+04,
#        8.87730263e+03, 1.54510770e+04, 1.25835599e+04, 7.55644870e+03,
#        9.09671510e+03, 1.72520617e+04, 4.10262904e+03, 1.16757639e+04,
#        8.14243924e+02, 6.65785697e+03, 1.56456923e+04, 2.63714527e+04,
#        2.71397517e+03, 9.02326133e+03, 3.82058315e+04, 1.59591791e+04,
#        1.17676664e+04, 2.82387107e+04, 1.09585547e+04, 5.35321025e+04,
#        5.70024583e+03, 1.20313742e+04, 2.56470058e+04, 5.73778627e+04,
#        1.61087906e+04, 1.37996185e+04, 1.74901820e+04, 3.56860254e+04,
#        1.37017670e+03, 1.39297950e+04, 3.48039406e+04, 3.38372393e+04,
#        8.36336981e+03, 2.43526972e+04, 3.50496001e+03, 3.08455980e+03,
#        1.89989037e+04, 3.54532243e+04, 9.53764676e+03, 3.16809925e+04,
#        1.24910779e+05, 4.51249341e+03, 7.23796068e+03, 2.83130199e+04,
#        1.30639893e+04, 4.10079388e+04, 3.65540526e+04, 2.41285783e+04,
#        5.39370967e+04, 6.16269156e+03, 4.30217753e+03, 1.72041244e+04,
#        1.16617442e+04, 3.08169660e+04, 4.25061982e+03, 9.56625185e+02,
#        3.43460120e+03, 1.78230162e+03, 2.44442487e+04, 2.30356234e+04,
#        1.65072508e+04, 3.35290325e+04, 1.37263072e+04, 4.09376349e+04,
#        5.05883247e+04, 1.96966143e+04, 1.27233500e+04])

# %%
#_ = plt.hist(trace2, bins=30, alpha=0.5, label='insurance claim - simulated')
_ = plt.hist(insurance, bins=get_num_bins(insurance), alpha=0.5, label='insurance claim - obsereved')
# _ = plt.hist(ins_model_rvs, bins=get_num_bins(ins_model_rvs), alpha=0.5, label='insurance claim - simulated')
_ = plt.hist(ins_model_rvs, bins=27, alpha=0.5, label='insurance claim - simulated')


_ = plt.xlabel('Charge amount')
_ = plt.ylabel('Frequency')
_ = plt.legend()

# need to make sure the number of bins is the same for both or else the result is skewed (bin bias!)

# %%
len(insurance), get_num_bins(insurance),  type(insurance)
# Out:
# (783, 16, pandas.core.series.Series)

# %%
len(ins_model_rvs), get_num_bins(ins_model_rvs), type(ins_model_rvs)
# Out:
# (783, 27, numpy.ndarray)

# %% [markdown]
# ## Summary

# %% [markdown]
# In this exercise, we have postulated a distribution to describe the individual charge amounts for non-insured cases. This distribution has two required parameters, which we do not know, but we used PyMC3 to perform Bayesian inference to find our level of "belief" in a range of values for them. We then used the average parameter values to create one simulated data set of the same size as the original, but the distribution of our posteriors for these parameters will allow us to perform simulations of any sample size we desire and for a range of scenarios of different $\alpha$ and $\beta$. This could be a powerful tool to model different financial conditions for the hospital.
#
# Well done making it through this tricky subject. Starting think Bayesian _and_ starting to get to grips with something like PyMC3 is no easy task. As a data scientist, the most important thing is to be aware that this statistical approach exists, though you may not actually use this approach as much as you use the other approaches you've learned about. Still, we encourage you to think of ways that this approach could apply to the work that you do in this course and throughout your career.
