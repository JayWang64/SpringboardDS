# %% [markdown]
# # Springboard Data Science Career Track - March 2 Cohort
#
# Date: 2020-05-18
#
# By:			Justin Huang | justin.j.huang@gmail.com
#
# Advisor:	Blake Arensdorf | blake.arensdorf@gmail.com

# %% [markdown]
# =============================================================
# # Unit 5.4.5 - Capstone Data Wrangling
# =============================================================

# %% [markdown]
# There are 3 sources files for this project:
#
# - 2 primary source files were found on kaggle (games_csv and teams_csv).
#     https://www.kaggle.com/nathanlauga/nba-games#games_details.csv
#
# - 1 secondary source file was created by myself (additional conference/division data for each team)

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the DataFrames
# =========================================

# %%
#Load Data

# games_csv = '../_raw data/nba games/games.csv'
# teams_csv = '../_raw data/nba games/teams.csv'
# teams_conf_div_csv = '../_raw data/nba games/teams_conf_div.csv'
games_csv = 'games.csv'
teams_csv = 'teams.csv'
teams_conf_div_csv = 'teams_conf_div.csv'


loading_games_df = pd.read_csv(games_csv, parse_dates=['GAME_DATE_EST'])
loading_teams_df = pd.read_csv(teams_csv)
loading_teams_conf_div_df = pd.read_csv(teams_conf_div_csv)

# %% [markdown]
# # Inspecting the _Teams_ DataFrame...
# ==============================================================

# %%
loading_teams_df.head(30)
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# 12          0  1610612751      1976      2019          BKN           Nets
# 13          0  1610612752      1946      2019          NYK         Knicks
# 14          0  1610612753      1989      2019          ORL          Magic
# 15          0  1610612754      1976      2019          IND         Pacers
# 16          0  1610612755      1949      2019          PHI          76ers
# 17          0  1610612756      1968      2019          PHX           Suns
# 18          0  1610612757      1970      2019          POR  Trail Blazers
# 19          0  1610612758      1948      2019          SAC          Kings
# 20          0  1610612759      1976      2019          SAS          Spurs
# 21          0  1610612760      1967      2019          OKC        Thunder
# 22          0  1610612761      1995      2019          TOR        Raptors
# 23          0  1610612762      1974      2019          UTA           Jazz
# 24          0  1610612763      1995      2019          MEM      Grizzlies
# 25          0  1610612764      1961      2019          WAS        Wizards
# 26          0  1610612765      1948      2019          DET        Pistons
# 27          0  1610612766      1988      2019          CHA        Hornets
# 28          0  1610612739      1970      2019          CLE      Cavaliers
# 29          0  1610612744      1946      2019          GSW       Warriors
#
#     YEARFOUNDED           CITY                       ARENA  ARENACAPACITY  \
# 0          1949        Atlanta            State Farm Arena        18729.0
# 1          1946         Boston                   TD Garden        18624.0
# 2          2002    New Orleans        Smoothie King Center            NaN
# 3          1966        Chicago               United Center        21711.0
# 4          1980         Dallas    American Airlines Center        19200.0
# 5          1976         Denver                Pepsi Center        19099.0
# 6          1967        Houston               Toyota Center        18104.0
# 7          1970    Los Angeles              Staples Center        19060.0
# 8          1948    Los Angeles              Staples Center        19060.0
# 9          1988          Miami      AmericanAirlines Arena        19600.0
# 10         1968      Milwaukee                Fiserv Forum        17500.0
# 11         1989      Minnesota               Target Center        19356.0
# 12         1976       Brooklyn             Barclays Center            NaN
# 13         1946       New York       Madison Square Garden        19763.0
# 14         1989        Orlando                Amway Center            0.0
# 15         1976        Indiana     Bankers Life Fieldhouse        18345.0
# 16         1949   Philadelphia          Wells Fargo Center            NaN
# 17         1968        Phoenix  Talking Stick Resort Arena            NaN
# 18         1970       Portland                 Moda Center        19980.0
# 19         1948     Sacramento             Golden 1 Center        17500.0
# 20         1976    San Antonio                 AT&T Center        18694.0
# 21         1967  Oklahoma City     Chesapeake Energy Arena        19163.0
# 22         1995        Toronto            Scotiabank Arena        19800.0
# 23         1974           Utah     Vivint Smart Home Arena        20148.0
# 24         1995        Memphis                  FedExForum        18119.0
# 25         1961     Washington           Capital One Arena        20647.0
# 26         1948        Detroit        Little Caesars Arena        21000.0
# 27         1988      Charlotte             Spectrum Center        19026.0
# 28         1970      Cleveland         Quicken Loans Arena        20562.0
# 29         1946   Golden State                Chase Center        19596.0
#
#                                   OWNER   GENERALMANAGER         HEADCOACH  \
# 0                          Tony Ressler   Travis Schlenk      Lloyd Pierce
# 1                         Wyc Grousbeck      Danny Ainge      Brad Stevens
# 2                            Tom Benson   Trajan Langdon      Alvin Gentry
# 3                       Jerry Reinsdorf       Gar Forman        Jim Boylen
# 4                            Mark Cuban    Donnie Nelson     Rick Carlisle
# 5                          Stan Kroenke     Tim Connelly    Michael Malone
# 6                       Tilman Fertitta      Daryl Morey     Mike D'Antoni
# 7                         Steve Ballmer   Michael Winger        Doc Rivers
# 8               Jerry Buss Family Trust      Rob Pelinka       Frank Vogel
# 9                          Micky Arison        Pat Riley    Erik Spoelstra
# 10            Wesley Edens & Marc Lasry        Jon Horst  Mike Budenholzer
# 11                          Glen Taylor     Scott Layden     Ryan Saunders
# 12                             Joe Tsai       Sean Marks    Kenny Atkinson
# 13            Cablevision (James Dolan)      Steve Mills     David Fizdale
# 14                           Rick DeVos     John Hammond    Steve Clifford
# 15                           Herb Simon  Kevin Pritchard     Nate McMillan
# 16                        Joshua Harris      Elton Brand       Brett Brown
# 17                        Robert Sarver      James Jones    Monty Williams
# 18                           Paul Allen      Neil Olshey      Terry Stotts
# 19                       Vivek Ranadive      Vlade Divac       Luke Walton
# 20                           Peter Holt     Brian Wright    Gregg Popovich
# 21                         Clay Bennett       Sam Presti     Billy Donovan
# 22  Maple Leaf Sports and Entertainment      Masai Ujiri        Nick Nurse
# 23                          Greg Miller   Dennis Lindsey       Quin Snyder
# 24                          Robert Pera     Zach Kleiman    Taylor Jenkins
# 25                          Ted Leonsis   Tommy Sheppard      Scott Brooks
# 26                            Tom Gores     Ed Stefanski       Dwane Casey
# 27                       Michael Jordan    Mitch Kupchak     James Borrego
# 28                          Dan Gilbert      Koby Altman      John Beilein
# 29                            Joe Lacob        Bob Myers        Steve Kerr
#
#                    DLEAGUEAFFILIATION
# 0                       Erie Bayhawks
# 1                     Maine Red Claws
# 2                        No Affiliate
# 3                    Windy City Bulls
# 4                       Texas Legends
# 5                        No Affiliate
# 6            Rio Grande Valley Vipers
# 7   Agua Caliente Clippers of Ontario
# 8                    South Bay Lakers
# 9                Sioux Falls Skyforce
# 10                     Wisconsin Herd
# 11                        Iowa Wolves
# 12                   Long Island Nets
# 13                 Westchester Knicks
# 14                     Lakeland Magic
# 15                Fort Wayne Mad Ants
# 16                Delaware Blue Coats
# 17              Northern Arizona Suns
# 18                       No Affiliate
# 19                     Stockton Kings
# 20                       Austin Spurs
# 21                 Oklahoma City Blue
# 22                        Raptors 905
# 23               Salt Lake City Stars
# 24                     Memphis Hustle
# 25                 Capital City Go-Go
# 26                 Grand Rapids Drive
# 27                   Greensboro Swarm
# 28                      Canton Charge
# 29                Santa Cruz Warriors

# %%
loading_teams_conf_div_df.head(30)
# Out:
#        TEAM_ID CONFERENCE   DIVISION
# 0   1610612737       East  Southeast
# 1   1610612738       East   Atlantic
# 2   1610612740       West  Southwest
# 3   1610612741       East    Central
# 4   1610612742       West  Southwest
# 5   1610612743       West  Northwest
# 6   1610612745       West  Southwest
# 7   1610612746       West    Pacific
# 8   1610612747       West    Pacific
# 9   1610612748       East  Southeast
# 10  1610612749       East    Central
# 11  1610612750       West  Northwest
# 12  1610612751       East   Atlantic
# 13  1610612752       East   Atlantic
# 14  1610612753       East  Southeast
# 15  1610612754       East    Central
# 16  1610612755       East   Atlantic
# 17  1610612756       West    Pacific
# 18  1610612757       West    Pacific
# 19  1610612758       West  Northwest
# 20  1610612759       West  Southwest
# 21  1610612760       West  Northwest
# 22  1610612761       East   Atlantic
# 23  1610612762       West  Northwest
# 24  1610612763       West  Southwest
# 25  1610612764       East  Southeast
# 26  1610612765       East    Central
# 27  1610612766       East  Southeast
# 28  1610612739       East    Central
# 29  1610612744       West    Pacific

# %%
loading_teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
# LEAGUE_ID             30 non-null int64
# TEAM_ID               30 non-null int64
# MIN_YEAR              30 non-null int64
# MAX_YEAR              30 non-null int64
# ABBREVIATION          30 non-null object
# NICKNAME              30 non-null object
# YEARFOUNDED           30 non-null int64
# CITY                  30 non-null object
# ARENA                 30 non-null object
# ARENACAPACITY         26 non-null float64
# OWNER                 30 non-null object
# GENERALMANAGER        30 non-null object
# HEADCOACH             30 non-null object
# DLEAGUEAFFILIATION    30 non-null object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 3.4+ KB

# %% [markdown]
# # Missing Data Observations For _Teams_ DataFrame:
#
# The 2 teams dataframes need to be merged so all common information can be contained in a single dataframe.
# (conference, divsion, etc.)
#
# Next is to create a final teams dataframe that will be used for the assignment with only the relevant columns. (For example, we don't care about who the Team Owner or General manager is, so those columns will be removed).

# %%
# This will be the Teams dataframe that will be used for the capstone
teams_df_subset = loading_teams_df[['TEAM_ID', 'ABBREVIATION', 'NICKNAME', 'CITY']]
teams_df_subset
# Out:
#        TEAM_ID ABBREVIATION       NICKNAME           CITY
# 0   1610612737          ATL          Hawks        Atlanta
# 1   1610612738          BOS        Celtics         Boston
# 2   1610612740          NOP       Pelicans    New Orleans
# 3   1610612741          CHI          Bulls        Chicago
# 4   1610612742          DAL      Mavericks         Dallas
# 5   1610612743          DEN        Nuggets         Denver
# 6   1610612745          HOU        Rockets        Houston
# 7   1610612746          LAC       Clippers    Los Angeles
# 8   1610612747          LAL         Lakers    Los Angeles
# 9   1610612748          MIA           Heat          Miami
# 10  1610612749          MIL          Bucks      Milwaukee
# 11  1610612750          MIN   Timberwolves      Minnesota
# 12  1610612751          BKN           Nets       Brooklyn
# 13  1610612752          NYK         Knicks       New York
# 14  1610612753          ORL          Magic        Orlando
# 15  1610612754          IND         Pacers        Indiana
# 16  1610612755          PHI          76ers   Philadelphia
# 17  1610612756          PHX           Suns        Phoenix
# 18  1610612757          POR  Trail Blazers       Portland
# 19  1610612758          SAC          Kings     Sacramento
# 20  1610612759          SAS          Spurs    San Antonio
# 21  1610612760          OKC        Thunder  Oklahoma City
# 22  1610612761          TOR        Raptors        Toronto
# 23  1610612762          UTA           Jazz           Utah
# 24  1610612763          MEM      Grizzlies        Memphis
# 25  1610612764          WAS        Wizards     Washington
# 26  1610612765          DET        Pistons        Detroit
# 27  1610612766          CHA        Hornets      Charlotte
# 28  1610612739          CLE      Cavaliers      Cleveland
# 29  1610612744          GSW       Warriors   Golden State

# %%
# merge/map the 2 teams dataframes with only the required columns
teams_df = pd.merge(teams_df_subset, loading_teams_conf_div_df, on='TEAM_ID')
teams_df
# Out:
#        TEAM_ID ABBREVIATION       NICKNAME           CITY CONFERENCE  \
# 0   1610612737          ATL          Hawks        Atlanta       East
# 1   1610612738          BOS        Celtics         Boston       East
# 2   1610612740          NOP       Pelicans    New Orleans       West
# 3   1610612741          CHI          Bulls        Chicago       East
# 4   1610612742          DAL      Mavericks         Dallas       West
# 5   1610612743          DEN        Nuggets         Denver       West
# 6   1610612745          HOU        Rockets        Houston       West
# 7   1610612746          LAC       Clippers    Los Angeles       West
# 8   1610612747          LAL         Lakers    Los Angeles       West
# 9   1610612748          MIA           Heat          Miami       East
# 10  1610612749          MIL          Bucks      Milwaukee       East
# 11  1610612750          MIN   Timberwolves      Minnesota       West
# 12  1610612751          BKN           Nets       Brooklyn       East
# 13  1610612752          NYK         Knicks       New York       East
# 14  1610612753          ORL          Magic        Orlando       East
# 15  1610612754          IND         Pacers        Indiana       East
# 16  1610612755          PHI          76ers   Philadelphia       East
# 17  1610612756          PHX           Suns        Phoenix       West
# 18  1610612757          POR  Trail Blazers       Portland       West
# 19  1610612758          SAC          Kings     Sacramento       West
# 20  1610612759          SAS          Spurs    San Antonio       West
# 21  1610612760          OKC        Thunder  Oklahoma City       West
# 22  1610612761          TOR        Raptors        Toronto       East
# 23  1610612762          UTA           Jazz           Utah       West
# 24  1610612763          MEM      Grizzlies        Memphis       West
# 25  1610612764          WAS        Wizards     Washington       East
# 26  1610612765          DET        Pistons        Detroit       East
# 27  1610612766          CHA        Hornets      Charlotte       East
# 28  1610612739          CLE      Cavaliers      Cleveland       East
# 29  1610612744          GSW       Warriors   Golden State       West
#
#      DIVISION
# 0   Southeast
# 1    Atlantic
# 2   Southwest
# 3     Central
# 4   Southwest
# 5   Northwest
# 6   Southwest
# 7     Pacific
# 8     Pacific
# 9   Southeast
# 10    Central
# 11  Northwest
# 12   Atlantic
# 13   Atlantic
# 14  Southeast
# 15    Central
# 16   Atlantic
# 17    Pacific
# 18    Pacific
# 19  Northwest
# 20  Southwest
# 21  Northwest
# 22   Atlantic
# 23  Northwest
# 24  Southwest
# 25  Southeast
# 26    Central
# 27  Southeast
# 28    Central
# 29    Pacific

# %%
teams_df.name = 'Teams'
teams_df.set_index('TEAM_ID', inplace=True)

# %% [markdown]
# # Summary
# =========================================
#
# Now we have a teams dataframe: [teams_df], ready for use.

# %%
teams_df
# Out:
#            ABBREVIATION       NICKNAME           CITY CONFERENCE   DIVISION
# TEAM_ID
# 1610612737          ATL          Hawks        Atlanta       East  Southeast
# 1610612738          BOS        Celtics         Boston       East   Atlantic
# 1610612740          NOP       Pelicans    New Orleans       West  Southwest
# 1610612741          CHI          Bulls        Chicago       East    Central
# 1610612742          DAL      Mavericks         Dallas       West  Southwest
# 1610612743          DEN        Nuggets         Denver       West  Northwest
# 1610612745          HOU        Rockets        Houston       West  Southwest
# 1610612746          LAC       Clippers    Los Angeles       West    Pacific
# 1610612747          LAL         Lakers    Los Angeles       West    Pacific
# 1610612748          MIA           Heat          Miami       East  Southeast
# 1610612749          MIL          Bucks      Milwaukee       East    Central
# 1610612750          MIN   Timberwolves      Minnesota       West  Northwest
# 1610612751          BKN           Nets       Brooklyn       East   Atlantic
# 1610612752          NYK         Knicks       New York       East   Atlantic
# 1610612753          ORL          Magic        Orlando       East  Southeast
# 1610612754          IND         Pacers        Indiana       East    Central
# 1610612755          PHI          76ers   Philadelphia       East   Atlantic
# 1610612756          PHX           Suns        Phoenix       West    Pacific
# 1610612757          POR  Trail Blazers       Portland       West    Pacific
# 1610612758          SAC          Kings     Sacramento       West  Northwest
# 1610612759          SAS          Spurs    San Antonio       West  Southwest
# 1610612760          OKC        Thunder  Oklahoma City       West  Northwest
# 1610612761          TOR        Raptors        Toronto       East   Atlantic
# 1610612762          UTA           Jazz           Utah       West  Northwest
# 1610612763          MEM      Grizzlies        Memphis       West  Southwest
# 1610612764          WAS        Wizards     Washington       East  Southeast
# 1610612765          DET        Pistons        Detroit       East    Central
# 1610612766          CHA        Hornets      Charlotte       East  Southeast
# 1610612739          CLE      Cavaliers      Cleveland       East    Central
# 1610612744          GSW       Warriors   Golden State       West    Pacific

# %% [markdown]
# # Inspecting the _Games_ DataFrame...
# ==============================================================

# %%
loading_games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2019    1610612766      85.0        0.354        0.900  ...      22.0
# 1    2019    1610612750      91.0        0.364        0.400  ...      19.0
# 2    2019    1610612746     136.0        0.592        0.805  ...      25.0
# 3    2019    1610612743     133.0        0.566        0.700  ...      38.0
# 4    2019    1610612758     106.0        0.407        0.885  ...      18.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      47.0    1610612749      93.0        0.402        0.762         0.226
# 1      57.0    1610612742     111.0        0.468        0.632         0.275
# 2      37.0    1610612755     130.0        0.505        0.650         0.488
# 3      41.0    1610612761     118.0        0.461        0.897         0.263
# 4      51.0    1610612765     100.0        0.413        0.667         0.429
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      20.0      61.0               0
# 1      28.0      56.0               0
# 2      27.0      37.0               1
# 3      24.0      36.0               1
# 4      23.0      42.0               1
#
# [5 rows x 21 columns]

# %% [markdown]
# # Missing Data Observations for *Games* DataFrame:
# 1) Date Parsing: Need to add multiple date slicer columns (Month, Year, etc.)
#
# 2) Team Names: Will be convinient to have Team Short/Full Names (TOR, Raptors, Toronto)
#
# 3) Game Types: Will be good to know game type (Pre Season, Regular Season, Post Season)

# %% [markdown]
# # 1) Dates Parsing

# %%
# Extracting the D, M, Y from the Game Date
loading_games_df['dt_MONTH'] = pd.DatetimeIndex(loading_games_df['GAME_DATE_EST']).month
loading_games_df['dt_YEAR'] = pd.DatetimeIndex(loading_games_df['GAME_DATE_EST']).year
loading_games_df['dt_YEAR_MONTH'] = pd.to_datetime(loading_games_df['GAME_DATE_EST']).dt.to_period('M')
loading_games_df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2020-03-01  21900895            Final    1610612766       1610612749
# 1        2020-03-01  21900896            Final    1610612750       1610612742
# 2        2020-03-01  21900897            Final    1610612746       1610612755
# 3        2020-03-01  21900898            Final    1610612743       1610612761
# 4        2020-03-01  21900899            Final    1610612758       1610612765
# ...             ...       ...              ...           ...              ...
# 23190    2014-10-06  11400007            Final    1610612737       1610612740
# 23191    2014-10-06  11400004            Final    1610612741       1610612764
# 23192    2014-10-06  11400005            Final    1610612747       1610612743
# 23193    2014-10-05  11400002            Final    1610612761       1610612758
# 23194    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 0        2019    1610612766      85.0        0.354        0.900  ...
# 1        2019    1610612750      91.0        0.364        0.400  ...
# 2        2019    1610612746     136.0        0.592        0.805  ...
# 3        2019    1610612743     133.0        0.566        0.700  ...
# 4        2019    1610612758     106.0        0.407        0.885  ...
# ...       ...           ...       ...          ...          ...  ...
# 23190    2014    1610612737      93.0        0.419        0.821  ...
# 23191    2014    1610612741      81.0        0.338        0.719  ...
# 23192    2014    1610612747      98.0        0.448        0.682  ...
# 23193    2014    1610612761      99.0        0.440        0.771  ...
# 23194    2014    1610612748      86.0        0.431        0.679  ...
#
#        PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 0          93.0        0.402        0.762         0.226      20.0      61.0
# 1         111.0        0.468        0.632         0.275      28.0      56.0
# 2         130.0        0.505        0.650         0.488      27.0      37.0
# 3         118.0        0.461        0.897         0.263      24.0      36.0
# 4         100.0        0.413        0.667         0.429      23.0      42.0
# ...         ...          ...          ...           ...       ...       ...
# 23190      87.0        0.366        0.643         0.375      17.0      43.0
# 23191      85.0        0.411        0.636         0.267      17.0      47.0
# 23192      95.0        0.387        0.659         0.500      19.0      43.0
# 23193      94.0        0.469        0.725         0.385      18.0      45.0
# 23194      98.0        0.462        0.706         0.438      19.0      42.0
#
#        HOME_TEAM_WINS  dt_MONTH  dt_YEAR  dt_YEAR_MONTH
# 0                   0         3     2020        2020-03
# 1                   0         3     2020        2020-03
# 2                   1         3     2020        2020-03
# 3                   1         3     2020        2020-03
# 4                   1         3     2020        2020-03
# ...               ...       ...      ...            ...
# 23190               1        10     2014        2014-10
# 23191               0        10     2014        2014-10
# 23192               1        10     2014        2014-10
# 23193               1        10     2014        2014-10
# 23194               0        10     2014        2014-10
#
# [23195 rows x 24 columns]

# %% [markdown]
# # 2) Team Names

# %%
# It would be convinient to have the full / short team names in our dataframe

games_teams_temp_df = loading_games_df[['GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID']]
games_teams_temp_df
# Out:
#         GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID
# 0      21900895    1610612766       1610612749
# 1      21900896    1610612750       1610612742
# 2      21900897    1610612746       1610612755
# 3      21900898    1610612743       1610612761
# 4      21900899    1610612758       1610612765
# ...         ...           ...              ...
# 23190  11400007    1610612737       1610612740
# 23191  11400004    1610612741       1610612764
# 23192  11400005    1610612747       1610612743
# 23193  11400002    1610612761       1610612758
# 23194  11400001    1610612748       1610612740
#
# [23195 rows x 3 columns]

# %%
# merge in names of home/visitor teams

games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['ABBREVIATION'], left_on='VISITOR_TEAM_ID', right_on='TEAM_ID')
games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['CITY'], left_on='VISITOR_TEAM_ID', right_on='TEAM_ID')
games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['NICKNAME'], left_on='VISITOR_TEAM_ID', right_on='TEAM_ID')


games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['ABBREVIATION'], left_on='HOME_TEAM_ID', right_on='TEAM_ID')
games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['CITY'], left_on='HOME_TEAM_ID', right_on='TEAM_ID')
games_teams_temp_df = pd.merge(games_teams_temp_df, teams_df['NICKNAME'], left_on='HOME_TEAM_ID', right_on='TEAM_ID')

games_teams_temp_df
# Out:
#         GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID ABBREVIATION_x     CITY_x  \
# 0      21900895    1610612766       1610612749            MIL  Milwaukee
# 1      21900669    1610612766       1610612749            MIL  Milwaukee
# 2      21300407    1610612766       1610612749            MIL  Milwaukee
# 3      21300228    1610612766       1610612749            MIL  Milwaukee
# 4      21201190    1610612766       1610612749            MIL  Milwaukee
# ...         ...           ...              ...            ...        ...
# 23190  21800594    1610612749       1610612762            UTA       Utah
# 23191  21700381    1610612749       1610612762            UTA       Utah
# 23192  21600860    1610612749       1610612762            UTA       Utah
# 23193  21501041    1610612749       1610612762            UTA       Utah
# 23194  21400638    1610612749       1610612762            UTA       Utah
#
#       NICKNAME_x ABBREVIATION_y     CITY_y NICKNAME_y
# 0          Bucks            CHA  Charlotte    Hornets
# 1          Bucks            CHA  Charlotte    Hornets
# 2          Bucks            CHA  Charlotte    Hornets
# 3          Bucks            CHA  Charlotte    Hornets
# 4          Bucks            CHA  Charlotte    Hornets
# ...          ...            ...        ...        ...
# 23190       Jazz            MIL  Milwaukee      Bucks
# 23191       Jazz            MIL  Milwaukee      Bucks
# 23192       Jazz            MIL  Milwaukee      Bucks
# 23193       Jazz            MIL  Milwaukee      Bucks
# 23194       Jazz            MIL  Milwaukee      Bucks
#
# [23195 rows x 9 columns]

# %%
# rename the columns
games_teams_temp_df.rename(columns={
    'ABBREVIATION_x':'HOME_TEAM_ABBR',
    'CITY_x':'HOME_TEAM_CITY',
    'NICKNAME_x':'HOME_TEAM_NICKNAME',
    
    'ABBREVIATION_y':'VISITOR_TEAM_ABBR',
    'CITY_y':'VISITOR_TEAM_CITY',
    'NICKNAME_y':'VISITOR_TEAM_NICKNAME',                                   
                                   }, inplace=True)

# %%
# double check the new column names:
games_teams_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23195 entries, 0 to 23194
# Data columns (total 9 columns):
# GAME_ID                  23195 non-null int64
# HOME_TEAM_ID             23195 non-null int64
# VISITOR_TEAM_ID          23195 non-null int64
# HOME_TEAM_ABBR           23195 non-null object
# HOME_TEAM_CITY           23195 non-null object
# HOME_TEAM_NICKNAME       23195 non-null object
# VISITOR_TEAM_ABBR        23195 non-null object
# VISITOR_TEAM_CITY        23195 non-null object
# VISITOR_TEAM_NICKNAME    23195 non-null object
# dtypes: int64(3), object(6)
# memory usage: 1.8+ MB

# %%
# merge together our temp dataframes to create the new, games df

games_df = pd.merge(loading_games_df, games_teams_temp_df)

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2020-03-01  21900895            Final    1610612766       1610612749
# 1        2020-03-01  21900896            Final    1610612750       1610612742
# 2        2020-03-01  21900897            Final    1610612746       1610612755
# 3        2020-03-01  21900898            Final    1610612743       1610612761
# 4        2020-03-01  21900899            Final    1610612758       1610612765
# ...             ...       ...              ...           ...              ...
# 23190    2014-10-06  11400007            Final    1610612737       1610612740
# 23191    2014-10-06  11400004            Final    1610612741       1610612764
# 23192    2014-10-06  11400005            Final    1610612747       1610612743
# 23193    2014-10-05  11400002            Final    1610612761       1610612758
# 23194    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 0        2019    1610612766      85.0        0.354        0.900  ...
# 1        2019    1610612750      91.0        0.364        0.400  ...
# 2        2019    1610612746     136.0        0.592        0.805  ...
# 3        2019    1610612743     133.0        0.566        0.700  ...
# 4        2019    1610612758     106.0        0.407        0.885  ...
# ...       ...           ...       ...          ...          ...  ...
# 23190    2014    1610612737      93.0        0.419        0.821  ...
# 23191    2014    1610612741      81.0        0.338        0.719  ...
# 23192    2014    1610612747      98.0        0.448        0.682  ...
# 23193    2014    1610612761      99.0        0.440        0.771  ...
# 23194    2014    1610612748      86.0        0.431        0.679  ...
#
#        HOME_TEAM_WINS  dt_MONTH  dt_YEAR  dt_YEAR_MONTH  HOME_TEAM_ABBR  \
# 0                   0         3     2020        2020-03             MIL
# 1                   0         3     2020        2020-03             DAL
# 2                   1         3     2020        2020-03             PHI
# 3                   1         3     2020        2020-03             TOR
# 4                   1         3     2020        2020-03             DET
# ...               ...       ...      ...            ...             ...
# 23190               1        10     2014        2014-10             NOP
# 23191               0        10     2014        2014-10             WAS
# 23192               1        10     2014        2014-10             DEN
# 23193               1        10     2014        2014-10             SAC
# 23194               0        10     2014        2014-10             NOP
#
#        HOME_TEAM_CITY  HOME_TEAM_NICKNAME  VISITOR_TEAM_ABBR  \
# 0           Milwaukee               Bucks                CHA
# 1              Dallas           Mavericks                MIN
# 2        Philadelphia               76ers                LAC
# 3             Toronto             Raptors                DEN
# 4             Detroit             Pistons                SAC
# ...               ...                 ...                ...
# 23190     New Orleans            Pelicans                ATL
# 23191      Washington             Wizards                CHI
# 23192          Denver             Nuggets                LAL
# 23193      Sacramento               Kings                TOR
# 23194     New Orleans            Pelicans                MIA
#
#        VISITOR_TEAM_CITY  VISITOR_TEAM_NICKNAME
# 0              Charlotte                Hornets
# 1              Minnesota           Timberwolves
# 2            Los Angeles               Clippers
# 3                 Denver                Nuggets
# 4             Sacramento                  Kings
# ...                  ...                    ...
# 23190            Atlanta                  Hawks
# 23191            Chicago                  Bulls
# 23192        Los Angeles                 Lakers
# 23193            Toronto                Raptors
# 23194              Miami                   Heat
#
# [23195 rows x 30 columns]

# %% [markdown]
# # 3) Game Type

# %%
# I would like to easily distinguish between the different game types:
# Pre Season, 
# Regular Season, 
# Post Season (aka Playoffs)

# My hypothesis is that I can use the GAMEE_ID to deduce the game type.
# 1XX = Pre Season
# 2XX = Regular Season
# 4XX = Post Season

# %%
# Next, I would like to extract the first digit from the GAME_ID and use that as basis to determine GAME_TYPE
games_type_df = pd.DataFrame()

games_type_df['GAME_ID'] = games_df['GAME_ID']
games_type_df['SEASON'] = games_df['SEASON']
games_type_df['dt_MONTH'] = games_df['dt_MONTH']
games_type_df['GAME_TYPE_CODE'] = games_df['GAME_ID'].apply(lambda x: str(x)[0:1])
games_type_df['GAME_TYPE_CODE'] = games_type_df['GAME_TYPE_CODE'].astype(int)
games_type_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23195 entries, 0 to 23194
# Data columns (total 4 columns):
# GAME_ID           23195 non-null int64
# SEASON            23195 non-null int64
# dt_MONTH          23195 non-null int64
# GAME_TYPE_CODE    23195 non-null int32
# dtypes: int32(1), int64(3)
# memory usage: 815.4 KB

# %%
def get_game_type(val):
    if int(val) == 1:
        return 'Pre Season'
    elif int(val) == 2:
        return 'Regular Season'
    elif int(val) == 4:
        return 'Post Season'
    else:
        return 'Unknown'

games_type_df['GAME_TYPE'] = games_type_df['GAME_TYPE_CODE'].apply(get_game_type)
games_type_df
# Out:
#         GAME_ID  SEASON  dt_MONTH  GAME_TYPE_CODE       GAME_TYPE
# 0      21900895    2019         3               2  Regular Season
# 1      21900896    2019         3               2  Regular Season
# 2      21900897    2019         3               2  Regular Season
# 3      21900898    2019         3               2  Regular Season
# 4      21900899    2019         3               2  Regular Season
# ...         ...     ...       ...             ...             ...
# 23190  11400007    2014        10               1      Pre Season
# 23191  11400004    2014        10               1      Pre Season
# 23192  11400005    2014        10               1      Pre Season
# 23193  11400002    2014        10               1      Pre Season
# 23194  11400001    2014        10               1      Pre Season
#
# [23195 rows x 5 columns]

# %%
# Spot checking Pre Season

preseason_games_df = games_type_df[games_type_df['GAME_TYPE_CODE'] == 1]

plt.hist(preseason_games_df.dt_MONTH)
plt.xticks(np.arange(8,13,1))
plt.show()
    
#preseason_games_df.dt_MONTH.plot(kind='hist')

# %%
# We can see all games take place in the months Oct. 
# The outliers are as a result of the strike season 2011-12. As well as a handful of games taking place in Sept.

# %%
# Spot checking Post Season

postseason_games_df = games_type_df[games_type_df['GAME_TYPE_CODE'] == 4]
postseason_games_df.dt_MONTH.plot(kind='hist')

plt.hist(postseason_games_df.dt_MONTH)
plt.xticks(np.arange(3,8,1))
plt.show()

# %%
# We can see all games take place in the months April, May , June!

# %% [markdown]
# Now we can merge our game_types dataframe together with the original loading dataframe to create our final games dataframe.

# %%
games_df = pd.merge(games_df, games_type_df)

# %% [markdown]
# # Summary: Games
# =========================================
#
# Now we have a games dataframe ready to use!

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2020-03-01  21900895            Final    1610612766       1610612749
# 1        2020-03-01  21900896            Final    1610612750       1610612742
# 2        2020-03-01  21900897            Final    1610612746       1610612755
# 3        2020-03-01  21900898            Final    1610612743       1610612761
# 4        2020-03-01  21900899            Final    1610612758       1610612765
# ...             ...       ...              ...           ...              ...
# 23190    2014-10-06  11400007            Final    1610612737       1610612740
# 23191    2014-10-06  11400004            Final    1610612741       1610612764
# 23192    2014-10-06  11400005            Final    1610612747       1610612743
# 23193    2014-10-05  11400002            Final    1610612761       1610612758
# 23194    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  dt_YEAR  \
# 0        2019    1610612766      85.0        0.354        0.900  ...     2020
# 1        2019    1610612750      91.0        0.364        0.400  ...     2020
# 2        2019    1610612746     136.0        0.592        0.805  ...     2020
# 3        2019    1610612743     133.0        0.566        0.700  ...     2020
# 4        2019    1610612758     106.0        0.407        0.885  ...     2020
# ...       ...           ...       ...          ...          ...  ...      ...
# 23190    2014    1610612737      93.0        0.419        0.821  ...     2014
# 23191    2014    1610612741      81.0        0.338        0.719  ...     2014
# 23192    2014    1610612747      98.0        0.448        0.682  ...     2014
# 23193    2014    1610612761      99.0        0.440        0.771  ...     2014
# 23194    2014    1610612748      86.0        0.431        0.679  ...     2014
#
#        dt_YEAR_MONTH  HOME_TEAM_ABBR  HOME_TEAM_CITY  HOME_TEAM_NICKNAME  \
# 0            2020-03             MIL       Milwaukee               Bucks
# 1            2020-03             DAL          Dallas           Mavericks
# 2            2020-03             PHI    Philadelphia               76ers
# 3            2020-03             TOR         Toronto             Raptors
# 4            2020-03             DET         Detroit             Pistons
# ...              ...             ...             ...                 ...
# 23190        2014-10             NOP     New Orleans            Pelicans
# 23191        2014-10             WAS      Washington             Wizards
# 23192        2014-10             DEN          Denver             Nuggets
# 23193        2014-10             SAC      Sacramento               Kings
# 23194        2014-10             NOP     New Orleans            Pelicans
#
#        VISITOR_TEAM_ABBR  VISITOR_TEAM_CITY  VISITOR_TEAM_NICKNAME  \
# 0                    CHA          Charlotte                Hornets
# 1                    MIN          Minnesota           Timberwolves
# 2                    LAC        Los Angeles               Clippers
# 3                    DEN             Denver                Nuggets
# 4                    SAC         Sacramento                  Kings
# ...                  ...                ...                    ...
# 23190                ATL            Atlanta                  Hawks
# 23191                CHI            Chicago                  Bulls
# 23192                LAL        Los Angeles                 Lakers
# 23193                TOR            Toronto                Raptors
# 23194                MIA              Miami                   Heat
#
#        GAME_TYPE_CODE       GAME_TYPE
# 0                   2  Regular Season
# 1                   2  Regular Season
# 2                   2  Regular Season
# 3                   2  Regular Season
# 4                   2  Regular Season
# ...               ...             ...
# 23190               1      Pre Season
# 23191               1      Pre Season
# 23192               1      Pre Season
# 23193               1      Pre Season
# 23194               1      Pre Season
#
# [23195 rows x 32 columns]

# %% [markdown]
# # Outliers
#
# =========================================

# %%
# Next I wish to examine the outliers, if any.
# For example, I expect to see a lower number of games for the "strike" season (2011).
# Otherwise expect to see 1230 regular season game per season (82 games x 30 teams / 2 teams per game)

# Below will prepare the data by aggregating and plotting in order to conduct a visual inspection.

# %%
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  dt_YEAR  \
# 0    2019    1610612766      85.0        0.354        0.900  ...     2020
# 1    2019    1610612750      91.0        0.364        0.400  ...     2020
# 2    2019    1610612746     136.0        0.592        0.805  ...     2020
# 3    2019    1610612743     133.0        0.566        0.700  ...     2020
# 4    2019    1610612758     106.0        0.407        0.885  ...     2020
#
#    dt_YEAR_MONTH  HOME_TEAM_ABBR  HOME_TEAM_CITY  HOME_TEAM_NICKNAME  \
# 0        2020-03             MIL       Milwaukee               Bucks
# 1        2020-03             DAL          Dallas           Mavericks
# 2        2020-03             PHI    Philadelphia               76ers
# 3        2020-03             TOR         Toronto             Raptors
# 4        2020-03             DET         Detroit             Pistons
#
#    VISITOR_TEAM_ABBR  VISITOR_TEAM_CITY  VISITOR_TEAM_NICKNAME  \
# 0                CHA          Charlotte                Hornets
# 1                MIN          Minnesota           Timberwolves
# 2                LAC        Los Angeles               Clippers
# 3                DEN             Denver                Nuggets
# 4                SAC         Sacramento                  Kings
#
#    GAME_TYPE_CODE       GAME_TYPE
# 0               2  Regular Season
# 1               2  Regular Season
# 2               2  Regular Season
# 3               2  Regular Season
# 4               2  Regular Season
#
# [5 rows x 32 columns]

# %%
game_type_df = games_df[['SEASON', 'GAME_TYPE']]
game_type_df
# Out:
#        SEASON       GAME_TYPE
# 0        2019  Regular Season
# 1        2019  Regular Season
# 2        2019  Regular Season
# 3        2019  Regular Season
# 4        2019  Regular Season
# ...       ...             ...
# 23190    2014      Pre Season
# 23191    2014      Pre Season
# 23192    2014      Pre Season
# 23193    2014      Pre Season
# 23194    2014      Pre Season
#
# [23195 rows x 2 columns]

# %% [markdown]
# # Preparing Games Data

# %%
game_type_group_df = game_type_df.groupby(['SEASON','GAME_TYPE']).agg(
    count_col=pd.NamedAgg(column='GAME_TYPE', aggfunc='count')
)
game_type_group_df
# Out:
#                        count_col
# SEASON GAME_TYPE
# 2003   Post Season            82
#        Pre Season            114
#        Regular Season       1189
# 2004   Post Season            84
#        Pre Season             48
#        Regular Season       1230
# 2005   Post Season            89
#        Pre Season            113
#        Regular Season       1230
# 2006   Post Season            79
#        Pre Season            110
#        Regular Season       1230
# 2007   Post Season            86
#        Pre Season             95
#        Regular Season       1230
# 2008   Post Season            85
#        Pre Season            110
#        Regular Season       1230
# 2009   Post Season            82
#        Pre Season            112
#        Regular Season       1230
# 2010   Post Season            81
#        Pre Season            111
#        Regular Season       1230
# 2011   Post Season            84
#        Pre Season             30
#        Regular Season        990
# 2012   Post Season            85
#        Pre Season            106
#        Regular Season       1229
# 2013   Post Season            89
#        Pre Season            108
#        Regular Season       1230
# 2014   Post Season            81
#        Pre Season            107
#        Regular Season       1230
# 2015   Post Season            86
#        Pre Season            100
#        Regular Season       1230
# 2016   Post Season            79
#        Pre Season             96
#        Regular Season       1230
# 2017   Post Season            82
#        Pre Season             70
#        Regular Season       1230
# 2018   Post Season            82
#        Pre Season             66
#        Regular Season       1230
# 2019   Pre Season             65
#        Regular Season        900

# %% [markdown]
# # Outliers: Regular Season

# %%
game_type_group_df.reset_index(inplace=True)
game_type_group_df
# Out:
#     SEASON       GAME_TYPE  count_col
# 0     2003     Post Season         82
# 1     2003      Pre Season        114
# 2     2003  Regular Season       1189
# 3     2004     Post Season         84
# 4     2004      Pre Season         48
# 5     2004  Regular Season       1230
# 6     2005     Post Season         89
# 7     2005      Pre Season        113
# 8     2005  Regular Season       1230
# 9     2006     Post Season         79
# 10    2006      Pre Season        110
# 11    2006  Regular Season       1230
# 12    2007     Post Season         86
# 13    2007      Pre Season         95
# 14    2007  Regular Season       1230
# 15    2008     Post Season         85
# 16    2008      Pre Season        110
# 17    2008  Regular Season       1230
# 18    2009     Post Season         82
# 19    2009      Pre Season        112
# 20    2009  Regular Season       1230
# 21    2010     Post Season         81
# 22    2010      Pre Season        111
# 23    2010  Regular Season       1230
# 24    2011     Post Season         84
# 25    2011      Pre Season         30
# 26    2011  Regular Season        990
# 27    2012     Post Season         85
# 28    2012      Pre Season        106
# 29    2012  Regular Season       1229
# 30    2013     Post Season         89
# 31    2013      Pre Season        108
# 32    2013  Regular Season       1230
# 33    2014     Post Season         81
# 34    2014      Pre Season        107
# 35    2014  Regular Season       1230
# 36    2015     Post Season         86
# 37    2015      Pre Season        100
# 38    2015  Regular Season       1230
# 39    2016     Post Season         79
# 40    2016      Pre Season         96
# 41    2016  Regular Season       1230
# 42    2017     Post Season         82
# 43    2017      Pre Season         70
# 44    2017  Regular Season       1230
# 45    2018     Post Season         82
# 46    2018      Pre Season         66
# 47    2018  Regular Season       1230
# 48    2019      Pre Season         65
# 49    2019  Regular Season        900

# %%
reg_season_df = game_type_group_df.query("GAME_TYPE == 'Regular Season'")
reg_season_df.drop('GAME_TYPE', axis=1, inplace=True)
reg_season_df.set_index('SEASON', inplace=True)
reg_season_df
# Out:
#         count_col
# SEASON
# 2003         1189
# 2004         1230
# 2005         1230
# 2006         1230
# 2007         1230
# 2008         1230
# 2009         1230
# 2010         1230
# 2011          990
# 2012         1229
# 2013         1230
# 2014         1230
# 2015         1230
# 2016         1230
# 2017         1230
# 2018         1230
# 2019          900

# %%
ax = reg_season_df.plot(kind='bar')
ax.set(xlabel="Season")
ax.set(ylabel="Qty Games")
ax.set(title="Regular Season Games")
ax.legend(['Games'])

# %% [markdown]
# # Regular Season Outliers Observations
#
# We can see that there are a handful of regular season outliers:
#
# 2003
# - missing 41 games (1230-1189)
#
# 2011
# - "strike" season. only has 990 games
#
# 2012
# - missing 1 game (has 1229 games)
#
# 2019
# - current season. kaggle data only has games up (and including) to March 1st 2020
# - missing games from March 2 2020 to Mar 11 2020 (inclusive)
# - March 12 2020 was when the remaining games was suspended due to COVID-19.
# - source: https://www.basketball-reference.com/leagues/NBA_2020_games-march.html

# %% [markdown]
# # Outliers: Post Season

# %%
game_type_group_df
# Out:
#     SEASON       GAME_TYPE  count_col
# 0     2003     Post Season         82
# 1     2003      Pre Season        114
# 2     2003  Regular Season       1189
# 3     2004     Post Season         84
# 4     2004      Pre Season         48
# 5     2004  Regular Season       1230
# 6     2005     Post Season         89
# 7     2005      Pre Season        113
# 8     2005  Regular Season       1230
# 9     2006     Post Season         79
# 10    2006      Pre Season        110
# 11    2006  Regular Season       1230
# 12    2007     Post Season         86
# 13    2007      Pre Season         95
# 14    2007  Regular Season       1230
# 15    2008     Post Season         85
# 16    2008      Pre Season        110
# 17    2008  Regular Season       1230
# 18    2009     Post Season         82
# 19    2009      Pre Season        112
# 20    2009  Regular Season       1230
# 21    2010     Post Season         81
# 22    2010      Pre Season        111
# 23    2010  Regular Season       1230
# 24    2011     Post Season         84
# 25    2011      Pre Season         30
# 26    2011  Regular Season        990
# 27    2012     Post Season         85
# 28    2012      Pre Season        106
# 29    2012  Regular Season       1229
# 30    2013     Post Season         89
# 31    2013      Pre Season        108
# 32    2013  Regular Season       1230
# 33    2014     Post Season         81
# 34    2014      Pre Season        107
# 35    2014  Regular Season       1230
# 36    2015     Post Season         86
# 37    2015      Pre Season        100
# 38    2015  Regular Season       1230
# 39    2016     Post Season         79
# 40    2016      Pre Season         96
# 41    2016  Regular Season       1230
# 42    2017     Post Season         82
# 43    2017      Pre Season         70
# 44    2017  Regular Season       1230
# 45    2018     Post Season         82
# 46    2018      Pre Season         66
# 47    2018  Regular Season       1230
# 48    2019      Pre Season         65
# 49    2019  Regular Season        900

# %%
post_season_df = game_type_group_df.query("GAME_TYPE == 'Post Season'")
post_season_df.drop('GAME_TYPE', axis=1, inplace=True)
post_season_df.set_index('SEASON', inplace=True)
post_season_df
# Out:
#         count_col
# SEASON
# 2003           82
# 2004           84
# 2005           89
# 2006           79
# 2007           86
# 2008           85
# 2009           82
# 2010           81
# 2011           84
# 2012           85
# 2013           89
# 2014           81
# 2015           86
# 2016           79
# 2017           82
# 2018           82

# %%
ax = post_season_df.plot(kind='bar')
ax.set(xlabel="Season")
ax.set(ylabel="Qty Games")
ax.set(title="Post Season Games")
ax.legend(['Games'])

# %% [markdown]
# # Post Season Outliers Observations
#
# We can see that number of post season games hovers around the 80 game mark.
# The fluctuations are most likely due to the best-of-7 games format:
# the first team to win 4 games is declared the winner of the series.
# In some cases the series can be finished in 4 games total while others might "go the distance" (7 games total).

# %% [markdown]
# # Conlusions

# %% [markdown]
# We can see above
#
# 1) Post Season Games are about the same every season
#
# 2) Pre Season Games we will ignore for this analysis
#
# 3) Regular Season Games, we are missing some games. If time permits, I will add them to the dataset:
#
# 2003
# - missing 41 games (1230-1189 = 41)
#
# 2012
# - missing 1 game (has 1229 games)
#
# 2019
# - current season. kaggle data only has games up (and including) to March 1st 2020
# - missing games from March 2 2020 to Mar 11 2020 (inclusive)
# - March 12 2020 was when the remaining games was suspended due to COVID-19.
# - source: https://www.basketball-reference.com/leagues/NBA_2020_games-march.html

# %%
# out put both dataframes to csv
# filter out pre season games don't use them bc they are non-competitve

# %% [markdown]
# # Output of clean file, ready for downstream usage

# %%
games_df_clean = games_df.query("GAME_TYPE != 'Pre Season'")
games_df_clean
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2020-03-01  21900895            Final    1610612766       1610612749
# 1        2020-03-01  21900896            Final    1610612750       1610612742
# 2        2020-03-01  21900897            Final    1610612746       1610612755
# 3        2020-03-01  21900898            Final    1610612743       1610612761
# 4        2020-03-01  21900899            Final    1610612758       1610612765
# ...             ...       ...              ...           ...              ...
# 23083    2014-10-29  21400014            Final    1610612758       1610612744
# 23084    2014-10-29  21400015            Final    1610612757       1610612760
# 23085    2014-10-28  21400001            Final    1610612740       1610612753
# 23086    2014-10-28  21400002            Final    1610612759       1610612742
# 23087    2014-10-28  21400003            Final    1610612747       1610612745
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  dt_YEAR  \
# 0        2019    1610612766      85.0        0.354        0.900  ...     2020
# 1        2019    1610612750      91.0        0.364        0.400  ...     2020
# 2        2019    1610612746     136.0        0.592        0.805  ...     2020
# 3        2019    1610612743     133.0        0.566        0.700  ...     2020
# 4        2019    1610612758     106.0        0.407        0.885  ...     2020
# ...       ...           ...       ...          ...          ...  ...      ...
# 23083    2014    1610612758      77.0        0.308        0.743  ...     2014
# 23084    2014    1610612757     106.0        0.448        0.773  ...     2014
# 23085    2014    1610612740     101.0        0.406        0.484  ...     2014
# 23086    2014    1610612759     101.0        0.529        0.813  ...     2014
# 23087    2014    1610612747      90.0        0.354        0.795  ...     2014
#
#        dt_YEAR_MONTH  HOME_TEAM_ABBR  HOME_TEAM_CITY  HOME_TEAM_NICKNAME  \
# 0            2020-03             MIL       Milwaukee               Bucks
# 1            2020-03             DAL          Dallas           Mavericks
# 2            2020-03             PHI    Philadelphia               76ers
# 3            2020-03             TOR         Toronto             Raptors
# 4            2020-03             DET         Detroit             Pistons
# ...              ...             ...             ...                 ...
# 23083        2014-10             GSW    Golden State            Warriors
# 23084        2014-10             OKC   Oklahoma City             Thunder
# 23085        2014-10             ORL         Orlando               Magic
# 23086        2014-10             DAL          Dallas           Mavericks
# 23087        2014-10             HOU         Houston             Rockets
#
#        VISITOR_TEAM_ABBR  VISITOR_TEAM_CITY  VISITOR_TEAM_NICKNAME  \
# 0                    CHA          Charlotte                Hornets
# 1                    MIN          Minnesota           Timberwolves
# 2                    LAC        Los Angeles               Clippers
# 3                    DEN             Denver                Nuggets
# 4                    SAC         Sacramento                  Kings
# ...                  ...                ...                    ...
# 23083                SAC         Sacramento                  Kings
# 23084                POR           Portland          Trail Blazers
# 23085                NOP        New Orleans               Pelicans
# 23086                SAS        San Antonio                  Spurs
# 23087                LAL        Los Angeles                 Lakers
#
#        GAME_TYPE_CODE       GAME_TYPE
# 0                   2  Regular Season
# 1                   2  Regular Season
# 2                   2  Regular Season
# 3                   2  Regular Season
# 4                   2  Regular Season
# ...               ...             ...
# 23083               2  Regular Season
# 23084               2  Regular Season
# 23085               2  Regular Season
# 23086               2  Regular Season
# 23087               2  Regular Season
#
# [21634 rows x 32 columns]

# %%
games_df_clean.to_csv('clean\games_clean.csv')

# %%
teams_df
# Out:
#            ABBREVIATION       NICKNAME           CITY CONFERENCE   DIVISION
# TEAM_ID
# 1610612737          ATL          Hawks        Atlanta       East  Southeast
# 1610612738          BOS        Celtics         Boston       East   Atlantic
# 1610612740          NOP       Pelicans    New Orleans       West  Southwest
# 1610612741          CHI          Bulls        Chicago       East    Central
# 1610612742          DAL      Mavericks         Dallas       West  Southwest
# 1610612743          DEN        Nuggets         Denver       West  Northwest
# 1610612745          HOU        Rockets        Houston       West  Southwest
# 1610612746          LAC       Clippers    Los Angeles       West    Pacific
# 1610612747          LAL         Lakers    Los Angeles       West    Pacific
# 1610612748          MIA           Heat          Miami       East  Southeast
# 1610612749          MIL          Bucks      Milwaukee       East    Central
# 1610612750          MIN   Timberwolves      Minnesota       West  Northwest
# 1610612751          BKN           Nets       Brooklyn       East   Atlantic
# 1610612752          NYK         Knicks       New York       East   Atlantic
# 1610612753          ORL          Magic        Orlando       East  Southeast
# 1610612754          IND         Pacers        Indiana       East    Central
# 1610612755          PHI          76ers   Philadelphia       East   Atlantic
# 1610612756          PHX           Suns        Phoenix       West    Pacific
# 1610612757          POR  Trail Blazers       Portland       West    Pacific
# 1610612758          SAC          Kings     Sacramento       West  Northwest
# 1610612759          SAS          Spurs    San Antonio       West  Southwest
# 1610612760          OKC        Thunder  Oklahoma City       West  Northwest
# 1610612761          TOR        Raptors        Toronto       East   Atlantic
# 1610612762          UTA           Jazz           Utah       West  Northwest
# 1610612763          MEM      Grizzlies        Memphis       West  Southwest
# 1610612764          WAS        Wizards     Washington       East  Southeast
# 1610612765          DET        Pistons        Detroit       East    Central
# 1610612766          CHA        Hornets      Charlotte       East  Southeast
# 1610612739          CLE      Cavaliers      Cleveland       East    Central
# 1610612744          GSW       Warriors   Golden State       West    Pacific

# %%
teams_df.to_csv('clean/teams_clean.csv')
